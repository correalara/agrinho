# %% [markdown]
# <a href="https://colab.research.google.com/github/correalara/agrinho/blob/main/aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 1** ⛲ ⏳ ⚖

# %%
aula = "IX"
print(f"{aula} aula de Python")
# Out:
# IX aula de Python

# %% [markdown]
# #**aula2** ♥ ⛓ ⛄

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 6 * livro_infantil
pontos rodrigo_ana = livro ficcao_infantil + livro_n_ ficcao_infaltil + 2 * livr_ficcao + 6 * livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do Ana são 52

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 6 * livro_infantil
pontos_rodrigo_ana = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do Ana são {pontos_ana}")
print(f"Os pontos totais de rodrigo e ana são {pontos_rodrigo_ana}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do Ana são 52
# Os pontos totais de rodrigo e ana são 76

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 6 * livro_infantil
pontos rodrigo_ana = livro ficcao_infantil + livro_n_ ficcao_infaltil + 2 * livr_ficcao + 6 * livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do Ana são 52

# %% [markdown]
# #**aula 3 tabuada** 💣 🐟 😢

# %%
def tabuada(numero):
   for contador in range(1, 11): # Gera números de 1 a 10
     print(f"{numero} x {contador} = {numero * contador} ")
numero = int(input ("Digite um número para ver sua tabuada:"))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# # **aula 4 IMC** ⏰ ⛸ ⛽

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 15
# Digite sua altura (em metros): 1
#
# Seu IMC é: 15.00
# Você está abaixo do peso.

# %% [markdown]
# #**aula 5 - Chatbot** ⛏ 🥸 🕒

# %%
print("Olá, sou seu assistente virtiual")
nome = input("digite seu nome: ")
print(f"Olá, {nome}, em que posso ajudar?")
assunto = input("qual o tema você deseja tratar? Pyton, Javascript ou Scratch: ")
# Out:
# Olá, sou seu assistente virtiual
